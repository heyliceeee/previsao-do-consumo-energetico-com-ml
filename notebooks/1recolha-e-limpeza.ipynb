# %% [markdown]
# # 🧪  Recolha e Limpeza

# %%
# Importar bibliotecas necessárias
import pandas as pd
import os
import requests
import holidays

# %%
df = pd.read_parquet('../datasets/consumos_horario_codigo_postal.parquet') # Abrir o dataset

# %%
df.dtypes  # Verificar tipos de dados
# Out:
# datahora         datetime64[ms, Europe/Lisbon]
# dt_consumo                              object
# hr_consumo                              object
# codigo_postal                           object
# consumo                                float64
# dia_semana                              object
# dtype: object

# %% [markdown]
# # Engenharia de features
# | Feature   | Para que serve?                                   |
# |-----------|---------------------------------------------------|
# | Day       | Captura ciclos diários                            |
# | Month     | Captura sazonalidade mensal                       |
# | IsWeekend | 1 se for sábado ou domingo, senão 0               |
# | TimeOfDay | Útil porque o consumo e diferente ao longo do dia |
# | Season    | 	Captura efeitos climáticos ou sazonais amplos    |

# %%
df['DateTime'] = pd.to_datetime(df['dt_consumo'].astype(str) + ' ' + df['hr_consumo'], format='%Y-%m-%d %H:%M') #  Criar a coluna DateTime

df['Date'] = df['dt_consumo'] #  Criar a coluna Date

df['Hour'] = pd.to_datetime(df['hr_consumo'], format='%H:%M').dt.hour # Extrair a hora como número inteiro (ex: 23 de '23:00')

df['ZipCode'] = df['codigo_postal'] #  Criar a coluna ZipCode

df['ActiveEnergy(kWh)'] = df['consumo'] #  Criar a coluna ActiveEnergy(kWh)

df['Day'] = df['DateTime'].dt.day #  Criar a coluna Day

df['Month'] = df['DateTime'].dt.month #  Criar a coluna Month

df['Year'] = df['DateTime'].dt.year #  Criar a coluna Year

df['IsWeekend'] = df['dia_semana'].isin(['Sábado', 'Domingo']).astype(int) #  Criar a coluna IsWeekend

#  Criar a coluna TimeOfDay
def classificar_periodo(hora):
    if 0 <= hora <= 6:
        return 'Noite'
    elif 7 <= hora <= 11:
        return 'Manhã'
    elif 12 <= hora <= 18:
        return 'Tarde'
    else:
        return 'Noite'

df['TimeOfDay'] = df['Hour'].apply(classificar_periodo)

df['DayOfTheWeek'] = df['dia_semana'] #  Criar a coluna DayOfTheWeek

#  Criar a coluna Season
def get_season(month):
    if month in [12, 1, 2]:
        return 'Inverno'
    elif month in [3, 4, 5]:
        return 'Primavera'
    elif month in [6, 7, 8]:
        return 'Verão'
    else:
        return 'Outono'

df['Season'] = df['Month'].apply(get_season)

# Criar a coluna IsHoliday
feriados_pt = holidays.Portugal(years=[2022, 2023])
df['IsHoliday'] = df['DateTime'].dt.date.isin(feriados_pt).astype(int)

df.drop(columns=['datahora', 'dt_consumo', 'hr_consumo', 'codigo_postal', 'consumo', 'dia_semana'], inplace=True) # Eliminar a coluna Date/Time

df.tail() # Mostra as ultimas 5 linhas do DataFrame df_total (útil para inspeção rápida dos dados)
# Out:
#                    DateTime        Date  Hour ZipCode  ActiveEnergy(kWh)  Day  \
# 3727434 2023-02-09 10:00:00  2023-02-09    10    4405       19433.670144    9
# 3727435 2023-02-14 10:00:00  2023-02-14    10    4870        2314.309648   14
# 3727436 2023-02-07 15:00:00  2023-02-07    15    4475      113968.770238    7
# 3727437 2023-02-23 21:00:00  2023-02-23    21    5350        1731.337009   23
# 3727438 2023-02-19 12:00:00  2023-02-19    12    3610        2519.575060   19
#
#          Month  Year  IsWeekend TimeOfDay DayOfTheWeek   Season  IsHoliday
# 3727434      2  2023          0     Manhã       Quinta  Inverno          0
# 3727435      2  2023          0     Manhã        Terça  Inverno          0
# 3727436      2  2023          0     Tarde        Terça  Inverno          0
# 3727437      2  2023          0     Noite       Quinta  Inverno          0
# 3727438      2  2023          1     Tarde      Domingo  Inverno          0

# %%
# Verifica valores ausentes ou duplicados
df.isnull().sum()
df.duplicated().sum()
# Out:
# 0

# %%
df = df.sort_values(by='DateTime').reset_index(drop=True) # ordenar os dados pela coluna Datetime

# %% [markdown]
# # Adicionar ao dataset, APIs referentes a temperatura, a densidade populacional e ao feriado

# %%
caminho_da_pasta = '../datasets/datasetsPorCP'

# Dividir o dataset por varios datasets, por codigo postal
for cp in df['ZipCode'].unique(): # Para cada código postal único no dataset
    if cp == "OUTROS":
        print(f"⚠️ A ignorar código postal inválido: {cp}")
        continue
    df_cp = df[df['ZipCode'] == cp].copy()
    df_cp.sort_values('DateTime', inplace=True)  # Ordenar por DateTime (por segurança)

    if not os.path.exists(caminho_da_pasta): # Verifique se a pasta já existe
        os.mkdir(caminho_da_pasta) # Crie a pasta
    caminho_ficheiro = f"{caminho_da_pasta}/consumo_{cp}.parquet"
    df_cp.to_parquet(caminho_ficheiro, index=False)  # Guardar como ficheiro parquet
    print(f"Ficheiro guardado: {caminho_ficheiro} ({len(df_cp)} registos)")
# Out:
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5000.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2450.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5230.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3620.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2800.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4780.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2410.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4585.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2380.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2985.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5350.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2480.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4000.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1400.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2050.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2560.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3720.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3430.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2825.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3880.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7490.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1675.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4970.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8365.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7800.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4935.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3770.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2810.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3500.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3025.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6150.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6260.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4650.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2700.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3360.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2635.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7580.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1070.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2675.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3630.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1500.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3090.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5155.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4485.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7565.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3740.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1600.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3700.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5210.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2855.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7960.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3420.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6300.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3450.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7250.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3305.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2840.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8125.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2590.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1000.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1495.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2460.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2780.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2950.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4600.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4810.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2100.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2860.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6350.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3525.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2680.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5070.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7570.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5430.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2240.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4820.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2250.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8600.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4770.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6060.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7480.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4960.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4775.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7320.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7900.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3670.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4405.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4715.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2890.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3840.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4825.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7300.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4515.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2790.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2620.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3460.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1150.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2775.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3260.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8900.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2660.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4460.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5060.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7555.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2525.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7340.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4900.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2230.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7230.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3220.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1800.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6000.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2500.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2735.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4615.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2710.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7425.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3505.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4430.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2260.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4750.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5030.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4815.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5340.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4860.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4480.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3080.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4455.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7220.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5140.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2350.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3440.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2835.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8135.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1885.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2600.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2395.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4990.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3830.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4415.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6040.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5050.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8150.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4705.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4450.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3475.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2580.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2865.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7750.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3040.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7170.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2650.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3060.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4880.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8000.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7160.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4605.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4465.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7000.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3550.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8700.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4420.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5130.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2490.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2965.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6360.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8300.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7670.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4785.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5040.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6050.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4050.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8670.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2785.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7470.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5370.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5150.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3350.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5090.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2640.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7080.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2330.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8375.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3780.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4890.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4250.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1170.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7920.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8100.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4745.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3560.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1700.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8800.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5320.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4350.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4580.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6440.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2540.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7440.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7630.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1990.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6270.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4560.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6400.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6320.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3020.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4730.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2970.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5110.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7450.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8950.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2685.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4550.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5120.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2130.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5470.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2440.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3750.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4830.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3520.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4500.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4710.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6090.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1350.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3650.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7540.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4765.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5450.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1250.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2445.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2705.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5400.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2300.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3200.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4840.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2205.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4575.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3515.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2495.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6355.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4495.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1900.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3660.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4400.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4760.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1200.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4640.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2150.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5300.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8005.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5335.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2750.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2805.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3100.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5385.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4950.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2415.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7860.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3465.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2715.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7400.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3860.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2910.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3510.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4630.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5100.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3000.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8400.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2765.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2760.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2975.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4620.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3320.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6160.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7645.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6285.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3045.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2200.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2655.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2610.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3885.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3050.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6120.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3280.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4910.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7700.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3610.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7830.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3680.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7940.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3140.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6030.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2870.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6250.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4099.parquet (8015 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8650.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4150.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2080.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2070.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2925.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3105.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2670.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6225.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6420.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1750.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7595.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4410.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4850.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2065.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4805.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4720.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4475.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4100.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7780.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4435.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2625.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5425.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7005.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4570.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3800.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8550.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1300.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2605.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7040.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2140.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4800.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3530.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2830.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3640.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5180.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4635.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2305.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2900.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3240.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7665.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2725.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3330.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2420.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3810.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4440.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2690.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4625.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3230.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4835.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2820.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2435.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4660.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6290.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2425.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4445.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2430.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2040.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7100.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2615.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3070.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2565.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2665.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2125.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2720.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4425.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4595.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2630.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7460.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3150.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2405.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4490.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7090.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3130.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7350.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1050.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1950.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8200.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4925.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4845.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2645.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6110.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1100.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6185.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2000.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5360.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2795.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3030.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4700.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7875.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4540.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4795.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4470.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5160.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4905.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4755.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4690.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2475.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4590.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4740.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6005.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3850.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7370.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4940.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2770.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4980.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2530.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5085.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2550.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4505.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6100.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2005.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4525.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2730.parquet (8016 registos)
# ⚠️ A ignorar código postal inválido: OUTROS
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8500.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7240.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5460.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5200.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7500.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4520.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3570.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4510.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3400.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4200.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7600.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3600.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4610.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2755.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2120.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2400.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2845.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2745.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2025.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6200.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6230.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2090.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4930.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7520.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6430.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4535.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7150.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3865.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3270.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2695.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_8970.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7885.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2485.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7330.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2520.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6215.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3405.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2135.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3300.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4920.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3730.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2740.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5225.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_6370.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2815.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3870.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_1685.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7050.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_3250.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7430.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4870.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2510.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_2955.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_4300.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_7200.parquet (8016 registos)
# Ficheiro guardado: ../datasets/datasetsPorCP/consumo_5445.parquet (8016 registos)

# %%
ficheiros = [f for f in os.listdir(caminho_da_pasta) if f.endswith(".parquet")] # Listar todos os ficheiros .parquet da pasta

# Guardar coordenadas em cache para não pedir várias vezes
coordenadas_por_distrito = {}
coordenadasConcelho_cache = {}

# Mapeamento simples de prefixos de CPs para distritos
prefixo_para_distrito = {
    range(1000, 2000): "Lisboa",
    range(2000, 2100): "Santarém",
    range(2100, 2300): "Lisboa",
    range(2300, 2400): "Santarém",
    range(2400, 2500): "Leiria",
    range(2500, 2700): "Lisboa",
    range(2700, 2800): "Lisboa",
    range(2800, 3000): "Setúbal",
    range(3000, 3100): "Coimbra",
    range(3100, 3300): "Leiria",
    range(3300, 3500): "Castelo Branco",
    range(3500, 3600): "Viseu",
    range(3600, 3700): "Viseu",
    range(3700, 3800): "Aveiro",
    range(3800, 3900): "Aveiro",
    range(3900, 4000): "Viseu",
    range(4000, 4200): "Porto",
    range(4200, 4400): "Porto",
    range(4400, 4500): "Vila Nova de Gaia",
    range(4500, 4600): "Penafiel",
    range(4600, 4700): "Amarante",
    range(4700, 4900): "Braga",
    range(4900, 5000): "Viana do Castelo",
    range(5000, 5100): "Vila Real",
    range(5100, 5400): "Bragança",
    range(5400, 5500): "Chaves",
    range(5500, 6000): "Bragança",
    range(6000, 6100): "Castelo Branco",
    range(6100, 6200): "Castelo Branco",
    range(6200, 6300): "Covilhã",
    range(6300, 6400): "Guarda",
    range(6400, 6500): "Guarda",
    range(7000, 7100): "Évora",
    range(7100, 7200): "Évora",
    range(7200, 7300): "Évora",
    range(7300, 7400): "Portalegre",
    range(7400, 7500): "Portalegre",
    range(7500, 7600): "Setúbal",
    range(7600, 7700): "Beja",
    range(7700, 7800): "Beja",
    range(7800, 7900): "Beja",
    range(7900, 8000): "Beja",
    range(8000, 8100): "Faro",
    range(8100, 8200): "Faro",
    range(8200, 8300): "Faro",
    range(8300, 8400): "Faro",
    range(8400, 8500): "Faro",
    range(8500, 8600): "Faro",
    range(8600, 8700): "Faro",
    range(8700, 8800): "Faro",
    range(8800, 8900): "Faro",
    range(8900, 9000): "Faro",
    range(9000, 9100): "Madeira",
    range(9100, 9200): "Madeira",
    range(9500, 9600): "Açores",
    range(9600, 9700): "Açores",
    range(9700, 9800): "Açores",
}

# Abrir o dataset referente a densidade populacional
df_densidadePopulacional = pd.read_csv('../datasets/ine_densidadePopulacional.csv', sep=";", skiprows=1, header=None, names=["RawConcelho", "Densidade"], encoding='utf-8')
df_densidadePopulacional[["ID_Concelho", "Concelho"]] = df_densidadePopulacional["RawConcelho"].str.split(":", expand=True) # Separa "1601:Arcos de Valdevez" em duas colunas
df_densidadePopulacional.drop(columns="RawConcelho", inplace=True) # Remove a coluna original
df_densidadePopulacional["Densidade"] = df_densidadePopulacional["Densidade"].str.replace(",", ".", regex=False).astype(float) # Corrige vírgula decimal

# %%
# Função auxiliar para obter distrito a partir do código postal
def obter_distrito(codigoPostal):
    try:
        prefixo = int(str(codigoPostal)[:4])
    except ValueError:
        return None  # Código postal inválido, como "OUTROS"

    for intervalo, distrito in prefixo_para_distrito.items():
        if prefixo in intervalo:
            return distrito
    return None  # Prefixo não mapeado

# %%
# Função para obter as coordenadas e concelho a partir do codigo postal
def obter_coordenadas_e_concelho(codigoPostal):
 # Ignora CPs que não pertençam a nenhum distrito conhecido
    # Ignora casos inválidos como "OUTROS"
    if not str(codigoPostal).isdigit():
        print(f"⚠️ A ignorar código postal inválido: {codigoPostal}")
        return None, None, None

    distrito = obter_distrito(codigoPostal)     # Verifica se já existem coordenadas em cache por distrito

    if distrito is None:
        print(f"⚠️ Código postal {codigoPostal} não está associado a nenhum distrito conhecido.")
        return None, None, None

    if distrito in coordenadas_por_distrito:
        return coordenadas_por_distrito[distrito]

    if codigoPostal in coordenadasConcelho_cache:
        return coordenadasConcelho_cache[codigoPostal]

    # Tenta obter coordenadas usando um CP representativo do distrito
    sufixos = [f"{i:03d}" for i in range(1, 1000, 2)]
    for sufixo in sufixos:
        url = f"https://www.cttcodigopostal.pt/api/v1/3d3ee9c11bb94d1ab881ff6133f48257/{codigoPostal}-{sufixo}"
        try:
            response = requests.get(url, timeout=5)
            response.raise_for_status()
            data = response.json()
            if data and isinstance(data, list):
                lat = float(data[0]["latitude"])
                lon = float(data[0]["longitude"])
                concelho = str(data[0]["concelho"])

                coordenadas_por_distrito[distrito] = (lat, lon, concelho)
                return lat, lon, concelho
        except requests.exceptions.RequestException:
            continue
        except Exception as e:
            print(f"⚠️ Erro inesperado em {codigoPostal}-{sufixo}: {e}")
            break

    print(f"❌ Falha: {codigoPostal} ({distrito}) sem coordenadas válidas")
    return None, None, None

# %%
# Função para obter a temperatura horária a partir das coordenadas
def obter_temperatura(lat, lon):
    url = "https://archive-api.open-meteo.com/v1/archive"  # URL da API de ficheiro histórico da Open-Meteo

    # Parâmetros da requisição, incluindo latitude, longitude, datas e tipo de dado (temperatura a 2 metros de altura)
    params = {
        "latitude": lat,
        "longitude": lon,
        "start_date": "2022-11-01", # Data de início do período
        "end_date": "2023-09-30", # Data de fim do período
        "hourly": "temperature_2m", # Dados horários de temperatura
        "timezone": "auto" # Fuso horário automático com base na localização
    }
    try:
        response = requests.get(url, params=params)  # Faz a requisição GET à API com os parâmetros definidos
        response.raise_for_status() # Lança uma exceção se a resposta indicar erro (ex: 404, 500, etc.)
        data = response.json() # Converte a resposta JSON num dicionário Python

        times = pd.to_datetime(data["hourly"]["time"]) # Converte a lista de datas/horas para objetos datetime do pandas
        temps = data["hourly"]["temperature_2m"] # Extrai a lista de temperaturas correspondentes
        df_temp = pd.DataFrame({"DateTime": times, "Temperature": temps}) # Cria um DataFrame com duas colunas: Data/Hora e Temperatura

        return df_temp # Retorna o DataFrame criado
    except Exception as e:
        print(f"❌ Erro ao obter temperaturas: {e}") # Em caso de erro (ex: ligação falhada, dados ausentes), imprime mensagem de erro

        return pd.DataFrame(columns=["DateTime", "Temperature"]) # Retorna um DataFrame vazio com as colunas esperadas

# %%
# Funcao para obter a densidade populacional do concelho
def obter_densidade_populacional(concelho):
    if concelho not in df_densidadePopulacional["Concelho"].values: # Verifica se o concelho existe na coluna "Concelho" do DataFrame df_densidadePopulacional
        print(f"⚠️ Não existe concelho '{concelho}' no dataset de densidade populacional") # Caso o concelho não exista, imprime um aviso e retorna None
        return None

    densidade = df_densidadePopulacional.loc[df_densidadePopulacional["Concelho"] == concelho, "Densidade"].values[0]  # Seleciona a densidade correspondente ao concelho dado

    return densidade # Retorna o valor da densidade populacional

# %%
# Na pasta datasetsPorCP, abrir cada dataset
for ficheiro in ficheiros:
    caminho_ficheiro = os.path.join(caminho_da_pasta, ficheiro) # Cria o caminho completo para o ficheiro atual
    df = pd.read_parquet(caminho_ficheiro) # Lê o ficheiro Parquet para um DataFrame
    df = df.sort_values("DateTime") # Ordena os dados pela coluna DateTime

    codigoPostal = str(df["ZipCode"].iloc[0]) # Obtém o código postal do primeiro registo (assumindo que todos os registos têm o mesmo CP)
    lat, lon, concelho = obter_coordenadas_e_concelho(codigoPostal) # Obtém latitude, longitude e concelho associados ao código postal

    # Se alguma coordenada ou concelho estiver em falta, ignora este ficheiro
    if lat is None or lon is None or concelho is None:
        print(f"⚠️ A saltar {codigoPostal} (sem coordenadas e/ou concelho)")
        continue

    df_temp = obter_temperatura(lat, lon) # Obtém as temperaturas horárias para as coordenadas dadas

    # Se não houver dados de temperatura, ignora este ficheiro
    if df_temp.empty:
        print(f"⚠️ Sem dados de temperatura para {codigoPostal}")
        continue

    # 🔄 Garante que ambas as colunas DateTime têm o mesmo formato (arredondado à hora)
    df["DateTime"] = pd.to_datetime(df["DateTime"]).dt.floor("h")
    df_temp["DateTime"] = pd.to_datetime(df_temp["DateTime"]).dt.floor("h")

    # 🔗 Junta os dados da temperatura ao DataFrame original com base na coluna DateTime
    df = pd.merge(df, df_temp, on="DateTime", how="left")

    # Verifica novamente o código postal (embora já tenha sido verificado antes)
    if codigoPostal is None :
        print(f"⚠️ A saltar {lat}, {lon} || {codigoPostal} (sem municipio)")
        continue

    # Adiciona a densidade populacional ao DataFrame, com base no concelho
    df["PopulationDensity"] = obter_densidade_populacional(concelho)

    # 💾 Guarda o DataFrame atualizado no mesmo ficheiro .parquet, sobrescrevendo-o
    df.to_parquet(caminho_ficheiro, index=False)
    print(f"✅ Ficheiro atualizado: {ficheiro}")
# Out:
# ✅ Ficheiro atualizado: consumo_1000.parquet
# ✅ Ficheiro atualizado: consumo_1050.parquet
# ✅ Ficheiro atualizado: consumo_1070.parquet
# ✅ Ficheiro atualizado: consumo_1100.parquet
# ✅ Ficheiro atualizado: consumo_1150.parquet
# ✅ Ficheiro atualizado: consumo_1170.parquet
# ✅ Ficheiro atualizado: consumo_1200.parquet
# ✅ Ficheiro atualizado: consumo_1250.parquet
# ✅ Ficheiro atualizado: consumo_1300.parquet
# ✅ Ficheiro atualizado: consumo_1350.parquet
# ✅ Ficheiro atualizado: consumo_1400.parquet
# ✅ Ficheiro atualizado: consumo_1495.parquet
# ✅ Ficheiro atualizado: consumo_1500.parquet
# ✅ Ficheiro atualizado: consumo_1600.parquet
# ✅ Ficheiro atualizado: consumo_1675.parquet
# ✅ Ficheiro atualizado: consumo_1685.parquet
# ✅ Ficheiro atualizado: consumo_1700.parquet
# ✅ Ficheiro atualizado: consumo_1750.parquet
# ✅ Ficheiro atualizado: consumo_1800.parquet
# ✅ Ficheiro atualizado: consumo_1885.parquet
# ✅ Ficheiro atualizado: consumo_1900.parquet
# ✅ Ficheiro atualizado: consumo_1950.parquet
# ✅ Ficheiro atualizado: consumo_1990.parquet
# ✅ Ficheiro atualizado: consumo_2000.parquet
# ✅ Ficheiro atualizado: consumo_2005.parquet
# ✅ Ficheiro atualizado: consumo_2025.parquet
# ✅ Ficheiro atualizado: consumo_2040.parquet
# ✅ Ficheiro atualizado: consumo_2050.parquet
# ✅ Ficheiro atualizado: consumo_2065.parquet
# ✅ Ficheiro atualizado: consumo_2070.parquet
# ✅ Ficheiro atualizado: consumo_2080.parquet
# ✅ Ficheiro atualizado: consumo_2090.parquet
# ✅ Ficheiro atualizado: consumo_2100.parquet
# ✅ Ficheiro atualizado: consumo_2120.parquet
# ✅ Ficheiro atualizado: consumo_2125.parquet
# ✅ Ficheiro atualizado: consumo_2130.parquet
# ✅ Ficheiro atualizado: consumo_2135.parquet
# ✅ Ficheiro atualizado: consumo_2140.parquet
# ✅ Ficheiro atualizado: consumo_2150.parquet
# ✅ Ficheiro atualizado: consumo_2200.parquet
# ✅ Ficheiro atualizado: consumo_2205.parquet
# ✅ Ficheiro atualizado: consumo_2230.parquet
# ✅ Ficheiro atualizado: consumo_2240.parquet
# ✅ Ficheiro atualizado: consumo_2250.parquet
# ✅ Ficheiro atualizado: consumo_2260.parquet
# ✅ Ficheiro atualizado: consumo_2300.parquet
# ✅ Ficheiro atualizado: consumo_2305.parquet
# ✅ Ficheiro atualizado: consumo_2330.parquet
# ✅ Ficheiro atualizado: consumo_2350.parquet
# ✅ Ficheiro atualizado: consumo_2380.parquet
# ✅ Ficheiro atualizado: consumo_2395.parquet
# ✅ Ficheiro atualizado: consumo_2400.parquet
# ✅ Ficheiro atualizado: consumo_2405.parquet
# ✅ Ficheiro atualizado: consumo_2410.parquet
# ✅ Ficheiro atualizado: consumo_2415.parquet
# ✅ Ficheiro atualizado: consumo_2420.parquet
# ✅ Ficheiro atualizado: consumo_2425.parquet
# ✅ Ficheiro atualizado: consumo_2430.parquet
# ✅ Ficheiro atualizado: consumo_2435.parquet
# ✅ Ficheiro atualizado: consumo_2440.parquet
# ✅ Ficheiro atualizado: consumo_2445.parquet
# ✅ Ficheiro atualizado: consumo_2450.parquet
# ✅ Ficheiro atualizado: consumo_2460.parquet
# ✅ Ficheiro atualizado: consumo_2475.parquet
# ✅ Ficheiro atualizado: consumo_2480.parquet
# ✅ Ficheiro atualizado: consumo_2485.parquet
# ✅ Ficheiro atualizado: consumo_2490.parquet
# ✅ Ficheiro atualizado: consumo_2495.parquet
# ✅ Ficheiro atualizado: consumo_2500.parquet
# ✅ Ficheiro atualizado: consumo_2510.parquet
# ✅ Ficheiro atualizado: consumo_2520.parquet
# ✅ Ficheiro atualizado: consumo_2525.parquet
# ✅ Ficheiro atualizado: consumo_2530.parquet
# ✅ Ficheiro atualizado: consumo_2540.parquet
# ✅ Ficheiro atualizado: consumo_2550.parquet
# ✅ Ficheiro atualizado: consumo_2560.parquet
# ✅ Ficheiro atualizado: consumo_2565.parquet
# ✅ Ficheiro atualizado: consumo_2580.parquet
# ✅ Ficheiro atualizado: consumo_2590.parquet
# ✅ Ficheiro atualizado: consumo_2600.parquet
# ✅ Ficheiro atualizado: consumo_2605.parquet
# ✅ Ficheiro atualizado: consumo_2610.parquet
# ✅ Ficheiro atualizado: consumo_2615.parquet
# ✅ Ficheiro atualizado: consumo_2620.parquet
# ✅ Ficheiro atualizado: consumo_2625.parquet
# ✅ Ficheiro atualizado: consumo_2630.parquet
# ✅ Ficheiro atualizado: consumo_2635.parquet
# ✅ Ficheiro atualizado: consumo_2640.parquet
# ✅ Ficheiro atualizado: consumo_2645.parquet
# ✅ Ficheiro atualizado: consumo_2650.parquet
# ✅ Ficheiro atualizado: consumo_2655.parquet
# ✅ Ficheiro atualizado: consumo_2660.parquet
# ✅ Ficheiro atualizado: consumo_2665.parquet
# ✅ Ficheiro atualizado: consumo_2670.parquet
# ✅ Ficheiro atualizado: consumo_2675.parquet
# ✅ Ficheiro atualizado: consumo_2680.parquet
# ✅ Ficheiro atualizado: consumo_2685.parquet
# ✅ Ficheiro atualizado: consumo_2690.parquet
# ✅ Ficheiro atualizado: consumo_2695.parquet
# ✅ Ficheiro atualizado: consumo_2700.parquet
# ✅ Ficheiro atualizado: consumo_2705.parquet
# ✅ Ficheiro atualizado: consumo_2710.parquet
# ✅ Ficheiro atualizado: consumo_2715.parquet
# ✅ Ficheiro atualizado: consumo_2720.parquet
# ✅ Ficheiro atualizado: consumo_2725.parquet
# ✅ Ficheiro atualizado: consumo_2730.parquet
# ✅ Ficheiro atualizado: consumo_2735.parquet
# ✅ Ficheiro atualizado: consumo_2740.parquet
# ✅ Ficheiro atualizado: consumo_2745.parquet
# ✅ Ficheiro atualizado: consumo_2750.parquet
# ✅ Ficheiro atualizado: consumo_2755.parquet
# ✅ Ficheiro atualizado: consumo_2760.parquet
# ✅ Ficheiro atualizado: consumo_2765.parquet
# ✅ Ficheiro atualizado: consumo_2770.parquet
# ✅ Ficheiro atualizado: consumo_2775.parquet
# ✅ Ficheiro atualizado: consumo_2780.parquet
# ✅ Ficheiro atualizado: consumo_2785.parquet
# ✅ Ficheiro atualizado: consumo_2790.parquet
# ✅ Ficheiro atualizado: consumo_2795.parquet
# ✅ Ficheiro atualizado: consumo_2800.parquet
# ✅ Ficheiro atualizado: consumo_2805.parquet
# ✅ Ficheiro atualizado: consumo_2810.parquet
# ✅ Ficheiro atualizado: consumo_2815.parquet
# ✅ Ficheiro atualizado: consumo_2820.parquet
# ✅ Ficheiro atualizado: consumo_2825.parquet
# ✅ Ficheiro atualizado: consumo_2830.parquet
# ✅ Ficheiro atualizado: consumo_2835.parquet
# ✅ Ficheiro atualizado: consumo_2840.parquet
# ✅ Ficheiro atualizado: consumo_2845.parquet
# ✅ Ficheiro atualizado: consumo_2855.parquet
# ✅ Ficheiro atualizado: consumo_2860.parquet
# ✅ Ficheiro atualizado: consumo_2865.parquet
# ✅ Ficheiro atualizado: consumo_2870.parquet
# ✅ Ficheiro atualizado: consumo_2890.parquet
# ✅ Ficheiro atualizado: consumo_2900.parquet
# ✅ Ficheiro atualizado: consumo_2910.parquet
# ✅ Ficheiro atualizado: consumo_2925.parquet
# ✅ Ficheiro atualizado: consumo_2950.parquet
# ✅ Ficheiro atualizado: consumo_2955.parquet
# ✅ Ficheiro atualizado: consumo_2965.parquet
# ✅ Ficheiro atualizado: consumo_2970.parquet
# ✅ Ficheiro atualizado: consumo_2975.parquet
# ✅ Ficheiro atualizado: consumo_2985.parquet
# ✅ Ficheiro atualizado: consumo_3000.parquet
# ✅ Ficheiro atualizado: consumo_3020.parquet
# ✅ Ficheiro atualizado: consumo_3025.parquet
# ✅ Ficheiro atualizado: consumo_3030.parquet
# ✅ Ficheiro atualizado: consumo_3040.parquet
# ✅ Ficheiro atualizado: consumo_3045.parquet
# ✅ Ficheiro atualizado: consumo_3050.parquet
# ✅ Ficheiro atualizado: consumo_3060.parquet
# ✅ Ficheiro atualizado: consumo_3070.parquet
# ✅ Ficheiro atualizado: consumo_3080.parquet
# ✅ Ficheiro atualizado: consumo_3090.parquet
# ✅ Ficheiro atualizado: consumo_3100.parquet
# ✅ Ficheiro atualizado: consumo_3105.parquet
# ✅ Ficheiro atualizado: consumo_3130.parquet
# ✅ Ficheiro atualizado: consumo_3140.parquet
# ✅ Ficheiro atualizado: consumo_3150.parquet
# ✅ Ficheiro atualizado: consumo_3200.parquet
# ✅ Ficheiro atualizado: consumo_3220.parquet
# ✅ Ficheiro atualizado: consumo_3230.parquet
# ✅ Ficheiro atualizado: consumo_3240.parquet
# ✅ Ficheiro atualizado: consumo_3250.parquet
# ✅ Ficheiro atualizado: consumo_3260.parquet
# ✅ Ficheiro atualizado: consumo_3270.parquet
# ✅ Ficheiro atualizado: consumo_3280.parquet
# ✅ Ficheiro atualizado: consumo_3300.parquet
# ✅ Ficheiro atualizado: consumo_3305.parquet
# ✅ Ficheiro atualizado: consumo_3320.parquet
# ✅ Ficheiro atualizado: consumo_3330.parquet
# ✅ Ficheiro atualizado: consumo_3350.parquet
# ✅ Ficheiro atualizado: consumo_3360.parquet
# ✅ Ficheiro atualizado: consumo_3400.parquet
# ✅ Ficheiro atualizado: consumo_3405.parquet
# ✅ Ficheiro atualizado: consumo_3420.parquet
# ✅ Ficheiro atualizado: consumo_3430.parquet
# ✅ Ficheiro atualizado: consumo_3440.parquet
# ✅ Ficheiro atualizado: consumo_3450.parquet
# ✅ Ficheiro atualizado: consumo_3460.parquet
# ✅ Ficheiro atualizado: consumo_3465.parquet
# ✅ Ficheiro atualizado: consumo_3475.parquet
# ✅ Ficheiro atualizado: consumo_3500.parquet
# ✅ Ficheiro atualizado: consumo_3505.parquet
# ✅ Ficheiro atualizado: consumo_3510.parquet
# ✅ Ficheiro atualizado: consumo_3515.parquet
# ✅ Ficheiro atualizado: consumo_3520.parquet
# ✅ Ficheiro atualizado: consumo_3525.parquet
# ✅ Ficheiro atualizado: consumo_3530.parquet
# ✅ Ficheiro atualizado: consumo_3550.parquet
# ✅ Ficheiro atualizado: consumo_3560.parquet
# ✅ Ficheiro atualizado: consumo_3570.parquet
# ✅ Ficheiro atualizado: consumo_3600.parquet
# ✅ Ficheiro atualizado: consumo_3610.parquet
# ✅ Ficheiro atualizado: consumo_3620.parquet
# ✅ Ficheiro atualizado: consumo_3630.parquet
# ✅ Ficheiro atualizado: consumo_3640.parquet
# ✅ Ficheiro atualizado: consumo_3650.parquet
# ✅ Ficheiro atualizado: consumo_3660.parquet
# ✅ Ficheiro atualizado: consumo_3670.parquet
# ✅ Ficheiro atualizado: consumo_3680.parquet
# ✅ Ficheiro atualizado: consumo_3700.parquet
# ✅ Ficheiro atualizado: consumo_3720.parquet
# ✅ Ficheiro atualizado: consumo_3730.parquet
# ✅ Ficheiro atualizado: consumo_3740.parquet
# ✅ Ficheiro atualizado: consumo_3750.parquet
# ✅ Ficheiro atualizado: consumo_3770.parquet
# ✅ Ficheiro atualizado: consumo_3780.parquet
# ✅ Ficheiro atualizado: consumo_3800.parquet
# ✅ Ficheiro atualizado: consumo_3810.parquet
# ✅ Ficheiro atualizado: consumo_3830.parquet
# ✅ Ficheiro atualizado: consumo_3840.parquet
# ✅ Ficheiro atualizado: consumo_3850.parquet
# ✅ Ficheiro atualizado: consumo_3860.parquet
# ✅ Ficheiro atualizado: consumo_3865.parquet
# ✅ Ficheiro atualizado: consumo_3870.parquet
# ✅ Ficheiro atualizado: consumo_3880.parquet
# ✅ Ficheiro atualizado: consumo_3885.parquet
# ✅ Ficheiro atualizado: consumo_4000.parquet
# ✅ Ficheiro atualizado: consumo_4050.parquet
# ✅ Ficheiro atualizado: consumo_4099.parquet
# ✅ Ficheiro atualizado: consumo_4100.parquet
# ✅ Ficheiro atualizado: consumo_4150.parquet
# ✅ Ficheiro atualizado: consumo_4200.parquet
# ✅ Ficheiro atualizado: consumo_4250.parquet
# ✅ Ficheiro atualizado: consumo_4300.parquet
# ✅ Ficheiro atualizado: consumo_4350.parquet
# ✅ Ficheiro atualizado: consumo_4400.parquet
# ✅ Ficheiro atualizado: consumo_4405.parquet
# ✅ Ficheiro atualizado: consumo_4410.parquet
# ✅ Ficheiro atualizado: consumo_4415.parquet
# ✅ Ficheiro atualizado: consumo_4420.parquet
# ✅ Ficheiro atualizado: consumo_4425.parquet
# ✅ Ficheiro atualizado: consumo_4430.parquet
# ✅ Ficheiro atualizado: consumo_4435.parquet
# ✅ Ficheiro atualizado: consumo_4440.parquet
# ✅ Ficheiro atualizado: consumo_4445.parquet
# ✅ Ficheiro atualizado: consumo_4450.parquet
# ✅ Ficheiro atualizado: consumo_4455.parquet
# ✅ Ficheiro atualizado: consumo_4460.parquet
# ✅ Ficheiro atualizado: consumo_4465.parquet
# ✅ Ficheiro atualizado: consumo_4470.parquet
# ✅ Ficheiro atualizado: consumo_4475.parquet
# ✅ Ficheiro atualizado: consumo_4480.parquet
# ✅ Ficheiro atualizado: consumo_4485.parquet
# ✅ Ficheiro atualizado: consumo_4490.parquet
# ✅ Ficheiro atualizado: consumo_4495.parquet
# ✅ Ficheiro atualizado: consumo_4500.parquet
# ✅ Ficheiro atualizado: consumo_4505.parquet
# ✅ Ficheiro atualizado: consumo_4510.parquet
# ✅ Ficheiro atualizado: consumo_4515.parquet
# ✅ Ficheiro atualizado: consumo_4520.parquet
# ✅ Ficheiro atualizado: consumo_4525.parquet
# ✅ Ficheiro atualizado: consumo_4535.parquet
# ✅ Ficheiro atualizado: consumo_4540.parquet
# ✅ Ficheiro atualizado: consumo_4550.parquet
# ✅ Ficheiro atualizado: consumo_4560.parquet
# ✅ Ficheiro atualizado: consumo_4570.parquet
# ✅ Ficheiro atualizado: consumo_4575.parquet
# ✅ Ficheiro atualizado: consumo_4580.parquet
# ✅ Ficheiro atualizado: consumo_4585.parquet
# ✅ Ficheiro atualizado: consumo_4590.parquet
# ✅ Ficheiro atualizado: consumo_4595.parquet
# ✅ Ficheiro atualizado: consumo_4600.parquet
# ✅ Ficheiro atualizado: consumo_4605.parquet
# ✅ Ficheiro atualizado: consumo_4610.parquet
# ✅ Ficheiro atualizado: consumo_4615.parquet
# ✅ Ficheiro atualizado: consumo_4620.parquet
# ✅ Ficheiro atualizado: consumo_4625.parquet
# ✅ Ficheiro atualizado: consumo_4630.parquet
# ✅ Ficheiro atualizado: consumo_4635.parquet
# ✅ Ficheiro atualizado: consumo_4640.parquet
# ✅ Ficheiro atualizado: consumo_4650.parquet
# ✅ Ficheiro atualizado: consumo_4660.parquet
# ✅ Ficheiro atualizado: consumo_4690.parquet
# ✅ Ficheiro atualizado: consumo_4700.parquet
# ✅ Ficheiro atualizado: consumo_4705.parquet
# ✅ Ficheiro atualizado: consumo_4710.parquet
# ✅ Ficheiro atualizado: consumo_4715.parquet
# ✅ Ficheiro atualizado: consumo_4720.parquet
# ✅ Ficheiro atualizado: consumo_4730.parquet
# ✅ Ficheiro atualizado: consumo_4740.parquet
# ✅ Ficheiro atualizado: consumo_4745.parquet
# ✅ Ficheiro atualizado: consumo_4750.parquet
# ✅ Ficheiro atualizado: consumo_4755.parquet
# ✅ Ficheiro atualizado: consumo_4760.parquet
# ✅ Ficheiro atualizado: consumo_4765.parquet
# ✅ Ficheiro atualizado: consumo_4770.parquet
# ✅ Ficheiro atualizado: consumo_4775.parquet
# ✅ Ficheiro atualizado: consumo_4780.parquet
# ✅ Ficheiro atualizado: consumo_4785.parquet
# ✅ Ficheiro atualizado: consumo_4795.parquet
# ✅ Ficheiro atualizado: consumo_4800.parquet
# ✅ Ficheiro atualizado: consumo_4805.parquet
# ✅ Ficheiro atualizado: consumo_4810.parquet
# ✅ Ficheiro atualizado: consumo_4815.parquet
# ✅ Ficheiro atualizado: consumo_4820.parquet
# ✅ Ficheiro atualizado: consumo_4825.parquet
# ✅ Ficheiro atualizado: consumo_4830.parquet
# ✅ Ficheiro atualizado: consumo_4835.parquet
# ✅ Ficheiro atualizado: consumo_4840.parquet
# ✅ Ficheiro atualizado: consumo_4845.parquet
# ✅ Ficheiro atualizado: consumo_4850.parquet
# ✅ Ficheiro atualizado: consumo_4860.parquet
# ✅ Ficheiro atualizado: consumo_4870.parquet
# ✅ Ficheiro atualizado: consumo_4880.parquet
# ✅ Ficheiro atualizado: consumo_4890.parquet
# ✅ Ficheiro atualizado: consumo_4900.parquet
# ✅ Ficheiro atualizado: consumo_4905.parquet
# ✅ Ficheiro atualizado: consumo_4910.parquet
# ✅ Ficheiro atualizado: consumo_4920.parquet
# ✅ Ficheiro atualizado: consumo_4925.parquet
# ✅ Ficheiro atualizado: consumo_4930.parquet
# ✅ Ficheiro atualizado: consumo_4935.parquet
# ✅ Ficheiro atualizado: consumo_4940.parquet
# ✅ Ficheiro atualizado: consumo_4950.parquet
# ✅ Ficheiro atualizado: consumo_4960.parquet
# ✅ Ficheiro atualizado: consumo_4970.parquet
# ✅ Ficheiro atualizado: consumo_4980.parquet
# ✅ Ficheiro atualizado: consumo_4990.parquet
# ✅ Ficheiro atualizado: consumo_5000.parquet
# ✅ Ficheiro atualizado: consumo_5030.parquet
# ✅ Ficheiro atualizado: consumo_5040.parquet
# ✅ Ficheiro atualizado: consumo_5050.parquet
# ✅ Ficheiro atualizado: consumo_5060.parquet
# ✅ Ficheiro atualizado: consumo_5070.parquet
# ✅ Ficheiro atualizado: consumo_5085.parquet
# ✅ Ficheiro atualizado: consumo_5090.parquet
# ✅ Ficheiro atualizado: consumo_5100.parquet
# ✅ Ficheiro atualizado: consumo_5110.parquet
# ✅ Ficheiro atualizado: consumo_5120.parquet
# ✅ Ficheiro atualizado: consumo_5130.parquet
# ✅ Ficheiro atualizado: consumo_5140.parquet
# ✅ Ficheiro atualizado: consumo_5150.parquet
# ✅ Ficheiro atualizado: consumo_5155.parquet
# ✅ Ficheiro atualizado: consumo_5160.parquet
# ✅ Ficheiro atualizado: consumo_5180.parquet
# ✅ Ficheiro atualizado: consumo_5200.parquet
# ✅ Ficheiro atualizado: consumo_5210.parquet
# ✅ Ficheiro atualizado: consumo_5225.parquet
# ✅ Ficheiro atualizado: consumo_5230.parquet
# ✅ Ficheiro atualizado: consumo_5300.parquet
# ✅ Ficheiro atualizado: consumo_5320.parquet
# ✅ Ficheiro atualizado: consumo_5335.parquet
# ✅ Ficheiro atualizado: consumo_5340.parquet
# ✅ Ficheiro atualizado: consumo_5350.parquet
# ✅ Ficheiro atualizado: consumo_5360.parquet
# ✅ Ficheiro atualizado: consumo_5370.parquet
# ✅ Ficheiro atualizado: consumo_5385.parquet
# ✅ Ficheiro atualizado: consumo_5400.parquet
# ✅ Ficheiro atualizado: consumo_5425.parquet
# ✅ Ficheiro atualizado: consumo_5430.parquet
# ✅ Ficheiro atualizado: consumo_5445.parquet
# ✅ Ficheiro atualizado: consumo_5450.parquet
# ✅ Ficheiro atualizado: consumo_5460.parquet
# ✅ Ficheiro atualizado: consumo_5470.parquet
# ✅ Ficheiro atualizado: consumo_6000.parquet
# ✅ Ficheiro atualizado: consumo_6005.parquet
# ✅ Ficheiro atualizado: consumo_6030.parquet
# ✅ Ficheiro atualizado: consumo_6040.parquet
# ✅ Ficheiro atualizado: consumo_6050.parquet
# ✅ Ficheiro atualizado: consumo_6060.parquet
# ✅ Ficheiro atualizado: consumo_6090.parquet
# ✅ Ficheiro atualizado: consumo_6100.parquet
# ✅ Ficheiro atualizado: consumo_6110.parquet
# ✅ Ficheiro atualizado: consumo_6120.parquet
# ✅ Ficheiro atualizado: consumo_6150.parquet
# ✅ Ficheiro atualizado: consumo_6160.parquet
# ✅ Ficheiro atualizado: consumo_6185.parquet
# ✅ Ficheiro atualizado: consumo_6200.parquet
# ✅ Ficheiro atualizado: consumo_6215.parquet
# ✅ Ficheiro atualizado: consumo_6225.parquet
# ✅ Ficheiro atualizado: consumo_6230.parquet
# ✅ Ficheiro atualizado: consumo_6250.parquet
# ✅ Ficheiro atualizado: consumo_6260.parquet
# ✅ Ficheiro atualizado: consumo_6270.parquet
# ✅ Ficheiro atualizado: consumo_6285.parquet
# ✅ Ficheiro atualizado: consumo_6290.parquet
# ✅ Ficheiro atualizado: consumo_6300.parquet
# ✅ Ficheiro atualizado: consumo_6320.parquet
# ✅ Ficheiro atualizado: consumo_6350.parquet
# ✅ Ficheiro atualizado: consumo_6355.parquet
# ✅ Ficheiro atualizado: consumo_6360.parquet
# ✅ Ficheiro atualizado: consumo_6370.parquet
# ✅ Ficheiro atualizado: consumo_6400.parquet
# ✅ Ficheiro atualizado: consumo_6420.parquet
# ✅ Ficheiro atualizado: consumo_6430.parquet
# ✅ Ficheiro atualizado: consumo_6440.parquet
# ✅ Ficheiro atualizado: consumo_7000.parquet
# ✅ Ficheiro atualizado: consumo_7005.parquet
# ✅ Ficheiro atualizado: consumo_7040.parquet
# ✅ Ficheiro atualizado: consumo_7050.parquet
# ✅ Ficheiro atualizado: consumo_7080.parquet
# ✅ Ficheiro atualizado: consumo_7090.parquet
# ✅ Ficheiro atualizado: consumo_7100.parquet
# ✅ Ficheiro atualizado: consumo_7150.parquet
# ✅ Ficheiro atualizado: consumo_7160.parquet
# ✅ Ficheiro atualizado: consumo_7170.parquet
# ✅ Ficheiro atualizado: consumo_7200.parquet
# ✅ Ficheiro atualizado: consumo_7220.parquet
# ✅ Ficheiro atualizado: consumo_7230.parquet
# ✅ Ficheiro atualizado: consumo_7240.parquet
# ✅ Ficheiro atualizado: consumo_7250.parquet
# ✅ Ficheiro atualizado: consumo_7300.parquet
# ✅ Ficheiro atualizado: consumo_7320.parquet
# ✅ Ficheiro atualizado: consumo_7330.parquet
# ✅ Ficheiro atualizado: consumo_7340.parquet
# ✅ Ficheiro atualizado: consumo_7350.parquet
# ✅ Ficheiro atualizado: consumo_7370.parquet
# ✅ Ficheiro atualizado: consumo_7400.parquet
# ✅ Ficheiro atualizado: consumo_7425.parquet
# ✅ Ficheiro atualizado: consumo_7430.parquet
# ✅ Ficheiro atualizado: consumo_7440.parquet
# ✅ Ficheiro atualizado: consumo_7450.parquet
# ✅ Ficheiro atualizado: consumo_7460.parquet
# ✅ Ficheiro atualizado: consumo_7470.parquet
# ✅ Ficheiro atualizado: consumo_7480.parquet
# ✅ Ficheiro atualizado: consumo_7490.parquet
# ✅ Ficheiro atualizado: consumo_7500.parquet
# ✅ Ficheiro atualizado: consumo_7520.parquet
# ✅ Ficheiro atualizado: consumo_7540.parquet
# ✅ Ficheiro atualizado: consumo_7555.parquet
# ✅ Ficheiro atualizado: consumo_7565.parquet
# ✅ Ficheiro atualizado: consumo_7570.parquet
# ✅ Ficheiro atualizado: consumo_7580.parquet
# ✅ Ficheiro atualizado: consumo_7595.parquet
# ✅ Ficheiro atualizado: consumo_7600.parquet
# ✅ Ficheiro atualizado: consumo_7630.parquet
# ✅ Ficheiro atualizado: consumo_7645.parquet
# ✅ Ficheiro atualizado: consumo_7665.parquet
# ✅ Ficheiro atualizado: consumo_7670.parquet
# ✅ Ficheiro atualizado: consumo_7700.parquet
# ✅ Ficheiro atualizado: consumo_7750.parquet
# ✅ Ficheiro atualizado: consumo_7780.parquet
# ✅ Ficheiro atualizado: consumo_7800.parquet
# ✅ Ficheiro atualizado: consumo_7830.parquet
# ✅ Ficheiro atualizado: consumo_7860.parquet
# ✅ Ficheiro atualizado: consumo_7875.parquet
# ✅ Ficheiro atualizado: consumo_7885.parquet
# ✅ Ficheiro atualizado: consumo_7900.parquet
# ✅ Ficheiro atualizado: consumo_7920.parquet
# ✅ Ficheiro atualizado: consumo_7940.parquet
# ✅ Ficheiro atualizado: consumo_7960.parquet
# ✅ Ficheiro atualizado: consumo_8000.parquet
# ✅ Ficheiro atualizado: consumo_8005.parquet
# ✅ Ficheiro atualizado: consumo_8100.parquet
# ✅ Ficheiro atualizado: consumo_8125.parquet
# ✅ Ficheiro atualizado: consumo_8135.parquet
# ✅ Ficheiro atualizado: consumo_8150.parquet
# ✅ Ficheiro atualizado: consumo_8200.parquet
# ✅ Ficheiro atualizado: consumo_8300.parquet
# ✅ Ficheiro atualizado: consumo_8365.parquet
# ✅ Ficheiro atualizado: consumo_8375.parquet
# ✅ Ficheiro atualizado: consumo_8400.parquet
# ✅ Ficheiro atualizado: consumo_8500.parquet
# ✅ Ficheiro atualizado: consumo_8550.parquet
# ✅ Ficheiro atualizado: consumo_8600.parquet
# ✅ Ficheiro atualizado: consumo_8650.parquet
# ✅ Ficheiro atualizado: consumo_8670.parquet
# ✅ Ficheiro atualizado: consumo_8700.parquet
# ✅ Ficheiro atualizado: consumo_8800.parquet
# ✅ Ficheiro atualizado: consumo_8900.parquet
# ✅ Ficheiro atualizado: consumo_8950.parquet
# ✅ Ficheiro atualizado: consumo_8970.parquet

# %% [markdown]
# # Unir todos os datasets num so

# %%
ficheiros = [f for f in os.listdir(caminho_da_pasta) if f.endswith(".parquet")] # Lista todos os ficheiros .parquet na pasta

dataframes = [] # Lista para acumular os DataFrames

# %%
# Ler e adicionar cada ficheiro à lista
for ficheiro in ficheiros:
    caminho_ficheiro = os.path.join(caminho_da_pasta, ficheiro) # Cria o caminho completo para o ficheiro atual
    df = pd.read_parquet(caminho_ficheiro) # Lê o ficheiro .parquet e armazena os dados num DataFrame
    dataframes.append(df) # Adiciona o DataFrame à lista "dataframes"

    print(f"✅ Lido: {ficheiro} ({len(df)} linhas)") # Imprime uma mensagem indicando que o ficheiro foi lido com sucesso e quantas linhas contém
# Out:
# ✅ Lido: consumo_1000.parquet (8016 linhas)
# ✅ Lido: consumo_1050.parquet (8016 linhas)
# ✅ Lido: consumo_1070.parquet (8016 linhas)
# ✅ Lido: consumo_1100.parquet (8016 linhas)
# ✅ Lido: consumo_1150.parquet (8016 linhas)
# ✅ Lido: consumo_1170.parquet (8016 linhas)
# ✅ Lido: consumo_1200.parquet (8016 linhas)
# ✅ Lido: consumo_1250.parquet (8016 linhas)
# ✅ Lido: consumo_1300.parquet (8016 linhas)
# ✅ Lido: consumo_1350.parquet (8016 linhas)
# ✅ Lido: consumo_1400.parquet (8016 linhas)
# ✅ Lido: consumo_1495.parquet (8016 linhas)
# ✅ Lido: consumo_1500.parquet (8016 linhas)
# ✅ Lido: consumo_1600.parquet (8016 linhas)
# ✅ Lido: consumo_1675.parquet (8016 linhas)
# ✅ Lido: consumo_1685.parquet (8016 linhas)
# ✅ Lido: consumo_1700.parquet (8016 linhas)
# ✅ Lido: consumo_1750.parquet (8016 linhas)
# ✅ Lido: consumo_1800.parquet (8016 linhas)
# ✅ Lido: consumo_1885.parquet (8016 linhas)
# ✅ Lido: consumo_1900.parquet (8016 linhas)
# ✅ Lido: consumo_1950.parquet (8016 linhas)
# ✅ Lido: consumo_1990.parquet (8016 linhas)
# ✅ Lido: consumo_2000.parquet (8016 linhas)
# ✅ Lido: consumo_2005.parquet (8016 linhas)
# ✅ Lido: consumo_2025.parquet (8016 linhas)
# ✅ Lido: consumo_2040.parquet (8016 linhas)
# ✅ Lido: consumo_2050.parquet (8016 linhas)
# ✅ Lido: consumo_2065.parquet (8016 linhas)
# ✅ Lido: consumo_2070.parquet (8016 linhas)
# ✅ Lido: consumo_2080.parquet (8016 linhas)
# ✅ Lido: consumo_2090.parquet (8016 linhas)
# ✅ Lido: consumo_2100.parquet (8016 linhas)
# ✅ Lido: consumo_2120.parquet (8016 linhas)
# ✅ Lido: consumo_2125.parquet (8016 linhas)
# ✅ Lido: consumo_2130.parquet (8016 linhas)
# ✅ Lido: consumo_2135.parquet (8016 linhas)
# ✅ Lido: consumo_2140.parquet (8016 linhas)
# ✅ Lido: consumo_2150.parquet (8016 linhas)
# ✅ Lido: consumo_2200.parquet (8016 linhas)
# ✅ Lido: consumo_2205.parquet (8016 linhas)
# ✅ Lido: consumo_2230.parquet (8016 linhas)
# ✅ Lido: consumo_2240.parquet (8016 linhas)
# ✅ Lido: consumo_2250.parquet (8016 linhas)
# ✅ Lido: consumo_2260.parquet (8016 linhas)
# ✅ Lido: consumo_2300.parquet (8016 linhas)
# ✅ Lido: consumo_2305.parquet (8016 linhas)
# ✅ Lido: consumo_2330.parquet (8016 linhas)
# ✅ Lido: consumo_2350.parquet (8016 linhas)
# ✅ Lido: consumo_2380.parquet (8016 linhas)
# ✅ Lido: consumo_2395.parquet (8016 linhas)
# ✅ Lido: consumo_2400.parquet (8016 linhas)
# ✅ Lido: consumo_2405.parquet (8016 linhas)
# ✅ Lido: consumo_2410.parquet (8016 linhas)
# ✅ Lido: consumo_2415.parquet (8016 linhas)
# ✅ Lido: consumo_2420.parquet (8016 linhas)
# ✅ Lido: consumo_2425.parquet (8016 linhas)
# ✅ Lido: consumo_2430.parquet (8016 linhas)
# ✅ Lido: consumo_2435.parquet (8016 linhas)
# ✅ Lido: consumo_2440.parquet (8016 linhas)
# ✅ Lido: consumo_2445.parquet (8016 linhas)
# ✅ Lido: consumo_2450.parquet (8016 linhas)
# ✅ Lido: consumo_2460.parquet (8016 linhas)
# ✅ Lido: consumo_2475.parquet (8016 linhas)
# ✅ Lido: consumo_2480.parquet (8016 linhas)
# ✅ Lido: consumo_2485.parquet (8016 linhas)
# ✅ Lido: consumo_2490.parquet (8016 linhas)
# ✅ Lido: consumo_2495.parquet (8016 linhas)
# ✅ Lido: consumo_2500.parquet (8016 linhas)
# ✅ Lido: consumo_2510.parquet (8016 linhas)
# ✅ Lido: consumo_2520.parquet (8016 linhas)
# ✅ Lido: consumo_2525.parquet (8016 linhas)
# ✅ Lido: consumo_2530.parquet (8016 linhas)
# ✅ Lido: consumo_2540.parquet (8016 linhas)
# ✅ Lido: consumo_2550.parquet (8016 linhas)
# ✅ Lido: consumo_2560.parquet (8016 linhas)
# ✅ Lido: consumo_2565.parquet (8016 linhas)
# ✅ Lido: consumo_2580.parquet (8016 linhas)
# ✅ Lido: consumo_2590.parquet (8016 linhas)
# ✅ Lido: consumo_2600.parquet (8016 linhas)
# ✅ Lido: consumo_2605.parquet (8016 linhas)
# ✅ Lido: consumo_2610.parquet (8016 linhas)
# ✅ Lido: consumo_2615.parquet (8016 linhas)
# ✅ Lido: consumo_2620.parquet (8016 linhas)
# ✅ Lido: consumo_2625.parquet (8016 linhas)
# ✅ Lido: consumo_2630.parquet (8016 linhas)
# ✅ Lido: consumo_2635.parquet (8016 linhas)
# ✅ Lido: consumo_2640.parquet (8016 linhas)
# ✅ Lido: consumo_2645.parquet (8016 linhas)
# ✅ Lido: consumo_2650.parquet (8016 linhas)
# ✅ Lido: consumo_2655.parquet (8016 linhas)
# ✅ Lido: consumo_2660.parquet (8016 linhas)
# ✅ Lido: consumo_2665.parquet (8016 linhas)
# ✅ Lido: consumo_2670.parquet (8016 linhas)
# ✅ Lido: consumo_2675.parquet (8016 linhas)
# ✅ Lido: consumo_2680.parquet (8016 linhas)
# ✅ Lido: consumo_2685.parquet (8016 linhas)
# ✅ Lido: consumo_2690.parquet (8016 linhas)
# ✅ Lido: consumo_2695.parquet (8016 linhas)
# ✅ Lido: consumo_2700.parquet (8016 linhas)
# ✅ Lido: consumo_2705.parquet (8016 linhas)
# ✅ Lido: consumo_2710.parquet (8016 linhas)
# ✅ Lido: consumo_2715.parquet (8016 linhas)
# ✅ Lido: consumo_2720.parquet (8016 linhas)
# ✅ Lido: consumo_2725.parquet (8016 linhas)
# ✅ Lido: consumo_2730.parquet (8016 linhas)
# ✅ Lido: consumo_2735.parquet (8016 linhas)
# ✅ Lido: consumo_2740.parquet (8016 linhas)
# ✅ Lido: consumo_2745.parquet (8016 linhas)
# ✅ Lido: consumo_2750.parquet (8016 linhas)
# ✅ Lido: consumo_2755.parquet (8016 linhas)
# ✅ Lido: consumo_2760.parquet (8016 linhas)
# ✅ Lido: consumo_2765.parquet (8016 linhas)
# ✅ Lido: consumo_2770.parquet (8016 linhas)
# ✅ Lido: consumo_2775.parquet (8016 linhas)
# ✅ Lido: consumo_2780.parquet (8016 linhas)
# ✅ Lido: consumo_2785.parquet (8016 linhas)
# ✅ Lido: consumo_2790.parquet (8016 linhas)
# ✅ Lido: consumo_2795.parquet (8016 linhas)
# ✅ Lido: consumo_2800.parquet (8016 linhas)
# ✅ Lido: consumo_2805.parquet (8016 linhas)
# ✅ Lido: consumo_2810.parquet (8016 linhas)
# ✅ Lido: consumo_2815.parquet (8016 linhas)
# ✅ Lido: consumo_2820.parquet (8016 linhas)
# ✅ Lido: consumo_2825.parquet (8016 linhas)
# ✅ Lido: consumo_2830.parquet (8016 linhas)
# ✅ Lido: consumo_2835.parquet (8016 linhas)
# ✅ Lido: consumo_2840.parquet (8016 linhas)
# ✅ Lido: consumo_2845.parquet (8016 linhas)
# ✅ Lido: consumo_2855.parquet (8016 linhas)
# ✅ Lido: consumo_2860.parquet (8016 linhas)
# ✅ Lido: consumo_2865.parquet (8016 linhas)
# ✅ Lido: consumo_2870.parquet (8016 linhas)
# ✅ Lido: consumo_2890.parquet (8016 linhas)
# ✅ Lido: consumo_2900.parquet (8016 linhas)
# ✅ Lido: consumo_2910.parquet (8016 linhas)
# ✅ Lido: consumo_2925.parquet (8016 linhas)
# ✅ Lido: consumo_2950.parquet (8016 linhas)
# ✅ Lido: consumo_2955.parquet (8016 linhas)
# ✅ Lido: consumo_2965.parquet (8016 linhas)
# ✅ Lido: consumo_2970.parquet (8016 linhas)
# ✅ Lido: consumo_2975.parquet (8016 linhas)
# ✅ Lido: consumo_2985.parquet (8016 linhas)
# ✅ Lido: consumo_3000.parquet (8016 linhas)
# ✅ Lido: consumo_3020.parquet (8016 linhas)
# ✅ Lido: consumo_3025.parquet (8016 linhas)
# ✅ Lido: consumo_3030.parquet (8016 linhas)
# ✅ Lido: consumo_3040.parquet (8016 linhas)
# ✅ Lido: consumo_3045.parquet (8016 linhas)
# ✅ Lido: consumo_3050.parquet (8016 linhas)
# ✅ Lido: consumo_3060.parquet (8016 linhas)
# ✅ Lido: consumo_3070.parquet (8016 linhas)
# ✅ Lido: consumo_3080.parquet (8016 linhas)
# ✅ Lido: consumo_3090.parquet (8016 linhas)
# ✅ Lido: consumo_3100.parquet (8016 linhas)
# ✅ Lido: consumo_3105.parquet (8016 linhas)
# ✅ Lido: consumo_3130.parquet (8016 linhas)
# ✅ Lido: consumo_3140.parquet (8016 linhas)
# ✅ Lido: consumo_3150.parquet (8016 linhas)
# ✅ Lido: consumo_3200.parquet (8016 linhas)
# ✅ Lido: consumo_3220.parquet (8016 linhas)
# ✅ Lido: consumo_3230.parquet (8016 linhas)
# ✅ Lido: consumo_3240.parquet (8016 linhas)
# ✅ Lido: consumo_3250.parquet (8016 linhas)
# ✅ Lido: consumo_3260.parquet (8016 linhas)
# ✅ Lido: consumo_3270.parquet (8016 linhas)
# ✅ Lido: consumo_3280.parquet (8016 linhas)
# ✅ Lido: consumo_3300.parquet (8016 linhas)
# ✅ Lido: consumo_3305.parquet (8016 linhas)
# ✅ Lido: consumo_3320.parquet (8016 linhas)
# ✅ Lido: consumo_3330.parquet (8016 linhas)
# ✅ Lido: consumo_3350.parquet (8016 linhas)
# ✅ Lido: consumo_3360.parquet (8016 linhas)
# ✅ Lido: consumo_3400.parquet (8016 linhas)
# ✅ Lido: consumo_3405.parquet (8016 linhas)
# ✅ Lido: consumo_3420.parquet (8016 linhas)
# ✅ Lido: consumo_3430.parquet (8016 linhas)
# ✅ Lido: consumo_3440.parquet (8016 linhas)
# ✅ Lido: consumo_3450.parquet (8016 linhas)
# ✅ Lido: consumo_3460.parquet (8016 linhas)
# ✅ Lido: consumo_3465.parquet (8016 linhas)
# ✅ Lido: consumo_3475.parquet (8016 linhas)
# ✅ Lido: consumo_3500.parquet (8016 linhas)
# ✅ Lido: consumo_3505.parquet (8016 linhas)
# ✅ Lido: consumo_3510.parquet (8016 linhas)
# ✅ Lido: consumo_3515.parquet (8016 linhas)
# ✅ Lido: consumo_3520.parquet (8016 linhas)
# ✅ Lido: consumo_3525.parquet (8016 linhas)
# ✅ Lido: consumo_3530.parquet (8016 linhas)
# ✅ Lido: consumo_3550.parquet (8016 linhas)
# ✅ Lido: consumo_3560.parquet (8016 linhas)
# ✅ Lido: consumo_3570.parquet (8016 linhas)
# ✅ Lido: consumo_3600.parquet (8016 linhas)
# ✅ Lido: consumo_3610.parquet (8016 linhas)
# ✅ Lido: consumo_3620.parquet (8016 linhas)
# ✅ Lido: consumo_3630.parquet (8016 linhas)
# ✅ Lido: consumo_3640.parquet (8016 linhas)
# ✅ Lido: consumo_3650.parquet (8016 linhas)
# ✅ Lido: consumo_3660.parquet (8016 linhas)
# ✅ Lido: consumo_3670.parquet (8016 linhas)
# ✅ Lido: consumo_3680.parquet (8016 linhas)
# ✅ Lido: consumo_3700.parquet (8016 linhas)
# ✅ Lido: consumo_3720.parquet (8016 linhas)
# ✅ Lido: consumo_3730.parquet (8016 linhas)
# ✅ Lido: consumo_3740.parquet (8016 linhas)
# ✅ Lido: consumo_3750.parquet (8016 linhas)
# ✅ Lido: consumo_3770.parquet (8016 linhas)
# ✅ Lido: consumo_3780.parquet (8016 linhas)
# ✅ Lido: consumo_3800.parquet (8016 linhas)
# ✅ Lido: consumo_3810.parquet (8016 linhas)
# ✅ Lido: consumo_3830.parquet (8016 linhas)
# ✅ Lido: consumo_3840.parquet (8016 linhas)
# ✅ Lido: consumo_3850.parquet (8016 linhas)
# ✅ Lido: consumo_3860.parquet (8016 linhas)
# ✅ Lido: consumo_3865.parquet (8016 linhas)
# ✅ Lido: consumo_3870.parquet (8016 linhas)
# ✅ Lido: consumo_3880.parquet (8016 linhas)
# ✅ Lido: consumo_3885.parquet (8016 linhas)
# ✅ Lido: consumo_4000.parquet (8016 linhas)
# ✅ Lido: consumo_4050.parquet (8016 linhas)
# ✅ Lido: consumo_4099.parquet (8015 linhas)
# ✅ Lido: consumo_4100.parquet (8016 linhas)
# ✅ Lido: consumo_4150.parquet (8016 linhas)
# ✅ Lido: consumo_4200.parquet (8016 linhas)
# ✅ Lido: consumo_4250.parquet (8016 linhas)
# ✅ Lido: consumo_4300.parquet (8016 linhas)
# ✅ Lido: consumo_4350.parquet (8016 linhas)
# ✅ Lido: consumo_4400.parquet (8016 linhas)
# ✅ Lido: consumo_4405.parquet (8016 linhas)
# ✅ Lido: consumo_4410.parquet (8016 linhas)
# ✅ Lido: consumo_4415.parquet (8016 linhas)
# ✅ Lido: consumo_4420.parquet (8016 linhas)
# ✅ Lido: consumo_4425.parquet (8016 linhas)
# ✅ Lido: consumo_4430.parquet (8016 linhas)
# ✅ Lido: consumo_4435.parquet (8016 linhas)
# ✅ Lido: consumo_4440.parquet (8016 linhas)
# ✅ Lido: consumo_4445.parquet (8016 linhas)
# ✅ Lido: consumo_4450.parquet (8016 linhas)
# ✅ Lido: consumo_4455.parquet (8016 linhas)
# ✅ Lido: consumo_4460.parquet (8016 linhas)
# ✅ Lido: consumo_4465.parquet (8016 linhas)
# ✅ Lido: consumo_4470.parquet (8016 linhas)
# ✅ Lido: consumo_4475.parquet (8016 linhas)
# ✅ Lido: consumo_4480.parquet (8016 linhas)
# ✅ Lido: consumo_4485.parquet (8016 linhas)
# ✅ Lido: consumo_4490.parquet (8016 linhas)
# ✅ Lido: consumo_4495.parquet (8016 linhas)
# ✅ Lido: consumo_4500.parquet (8016 linhas)
# ✅ Lido: consumo_4505.parquet (8016 linhas)
# ✅ Lido: consumo_4510.parquet (8016 linhas)
# ✅ Lido: consumo_4515.parquet (8016 linhas)
# ✅ Lido: consumo_4520.parquet (8016 linhas)
# ✅ Lido: consumo_4525.parquet (8016 linhas)
# ✅ Lido: consumo_4535.parquet (8016 linhas)
# ✅ Lido: consumo_4540.parquet (8016 linhas)
# ✅ Lido: consumo_4550.parquet (8016 linhas)
# ✅ Lido: consumo_4560.parquet (8016 linhas)
# ✅ Lido: consumo_4570.parquet (8016 linhas)
# ✅ Lido: consumo_4575.parquet (8016 linhas)
# ✅ Lido: consumo_4580.parquet (8016 linhas)
# ✅ Lido: consumo_4585.parquet (8016 linhas)
# ✅ Lido: consumo_4590.parquet (8016 linhas)
# ✅ Lido: consumo_4595.parquet (8016 linhas)
# ✅ Lido: consumo_4600.parquet (8016 linhas)
# ✅ Lido: consumo_4605.parquet (8016 linhas)
# ✅ Lido: consumo_4610.parquet (8016 linhas)
# ✅ Lido: consumo_4615.parquet (8016 linhas)
# ✅ Lido: consumo_4620.parquet (8016 linhas)
# ✅ Lido: consumo_4625.parquet (8016 linhas)
# ✅ Lido: consumo_4630.parquet (8016 linhas)
# ✅ Lido: consumo_4635.parquet (8016 linhas)
# ✅ Lido: consumo_4640.parquet (8016 linhas)
# ✅ Lido: consumo_4650.parquet (8016 linhas)
# ✅ Lido: consumo_4660.parquet (8016 linhas)
# ✅ Lido: consumo_4690.parquet (8016 linhas)
# ✅ Lido: consumo_4700.parquet (8016 linhas)
# ✅ Lido: consumo_4705.parquet (8016 linhas)
# ✅ Lido: consumo_4710.parquet (8016 linhas)
# ✅ Lido: consumo_4715.parquet (8016 linhas)
# ✅ Lido: consumo_4720.parquet (8016 linhas)
# ✅ Lido: consumo_4730.parquet (8016 linhas)
# ✅ Lido: consumo_4740.parquet (8016 linhas)
# ✅ Lido: consumo_4745.parquet (8016 linhas)
# ✅ Lido: consumo_4750.parquet (8016 linhas)
# ✅ Lido: consumo_4755.parquet (8016 linhas)
# ✅ Lido: consumo_4760.parquet (8016 linhas)
# ✅ Lido: consumo_4765.parquet (8016 linhas)
# ✅ Lido: consumo_4770.parquet (8016 linhas)
# ✅ Lido: consumo_4775.parquet (8016 linhas)
# ✅ Lido: consumo_4780.parquet (8016 linhas)
# ✅ Lido: consumo_4785.parquet (8016 linhas)
# ✅ Lido: consumo_4795.parquet (8016 linhas)
# ✅ Lido: consumo_4800.parquet (8016 linhas)
# ✅ Lido: consumo_4805.parquet (8016 linhas)
# ✅ Lido: consumo_4810.parquet (8016 linhas)
# ✅ Lido: consumo_4815.parquet (8016 linhas)
# ✅ Lido: consumo_4820.parquet (8016 linhas)
# ✅ Lido: consumo_4825.parquet (8016 linhas)
# ✅ Lido: consumo_4830.parquet (8016 linhas)
# ✅ Lido: consumo_4835.parquet (8016 linhas)
# ✅ Lido: consumo_4840.parquet (8016 linhas)
# ✅ Lido: consumo_4845.parquet (8016 linhas)
# ✅ Lido: consumo_4850.parquet (8016 linhas)
# ✅ Lido: consumo_4860.parquet (8016 linhas)
# ✅ Lido: consumo_4870.parquet (8016 linhas)
# ✅ Lido: consumo_4880.parquet (8016 linhas)
# ✅ Lido: consumo_4890.parquet (8016 linhas)
# ✅ Lido: consumo_4900.parquet (8016 linhas)
# ✅ Lido: consumo_4905.parquet (8016 linhas)
# ✅ Lido: consumo_4910.parquet (8016 linhas)
# ✅ Lido: consumo_4920.parquet (8016 linhas)
# ✅ Lido: consumo_4925.parquet (8016 linhas)
# ✅ Lido: consumo_4930.parquet (8016 linhas)
# ✅ Lido: consumo_4935.parquet (8016 linhas)
# ✅ Lido: consumo_4940.parquet (8016 linhas)
# ✅ Lido: consumo_4950.parquet (8016 linhas)
# ✅ Lido: consumo_4960.parquet (8016 linhas)
# ✅ Lido: consumo_4970.parquet (8016 linhas)
# ✅ Lido: consumo_4980.parquet (8016 linhas)
# ✅ Lido: consumo_4990.parquet (8016 linhas)
# ✅ Lido: consumo_5000.parquet (8016 linhas)
# ✅ Lido: consumo_5030.parquet (8016 linhas)
# ✅ Lido: consumo_5040.parquet (8016 linhas)
# ✅ Lido: consumo_5050.parquet (8016 linhas)
# ✅ Lido: consumo_5060.parquet (8016 linhas)
# ✅ Lido: consumo_5070.parquet (8016 linhas)
# ✅ Lido: consumo_5085.parquet (8016 linhas)
# ✅ Lido: consumo_5090.parquet (8016 linhas)
# ✅ Lido: consumo_5100.parquet (8016 linhas)
# ✅ Lido: consumo_5110.parquet (8016 linhas)
# ✅ Lido: consumo_5120.parquet (8016 linhas)
# ✅ Lido: consumo_5130.parquet (8016 linhas)
# ✅ Lido: consumo_5140.parquet (8016 linhas)
# ✅ Lido: consumo_5150.parquet (8016 linhas)
# ✅ Lido: consumo_5155.parquet (8016 linhas)
# ✅ Lido: consumo_5160.parquet (8016 linhas)
# ✅ Lido: consumo_5180.parquet (8016 linhas)
# ✅ Lido: consumo_5200.parquet (8016 linhas)
# ✅ Lido: consumo_5210.parquet (8016 linhas)
# ✅ Lido: consumo_5225.parquet (8016 linhas)
# ✅ Lido: consumo_5230.parquet (8016 linhas)
# ✅ Lido: consumo_5300.parquet (8016 linhas)
# ✅ Lido: consumo_5320.parquet (8016 linhas)
# ✅ Lido: consumo_5335.parquet (8016 linhas)
# ✅ Lido: consumo_5340.parquet (8016 linhas)
# ✅ Lido: consumo_5350.parquet (8016 linhas)
# ✅ Lido: consumo_5360.parquet (8016 linhas)
# ✅ Lido: consumo_5370.parquet (8016 linhas)
# ✅ Lido: consumo_5385.parquet (8016 linhas)
# ✅ Lido: consumo_5400.parquet (8016 linhas)
# ✅ Lido: consumo_5425.parquet (8016 linhas)
# ✅ Lido: consumo_5430.parquet (8016 linhas)
# ✅ Lido: consumo_5445.parquet (8016 linhas)
# ✅ Lido: consumo_5450.parquet (8016 linhas)
# ✅ Lido: consumo_5460.parquet (8016 linhas)
# ✅ Lido: consumo_5470.parquet (8016 linhas)
# ✅ Lido: consumo_6000.parquet (8016 linhas)
# ✅ Lido: consumo_6005.parquet (8016 linhas)
# ✅ Lido: consumo_6030.parquet (8016 linhas)
# ✅ Lido: consumo_6040.parquet (8016 linhas)
# ✅ Lido: consumo_6050.parquet (8016 linhas)
# ✅ Lido: consumo_6060.parquet (8016 linhas)
# ✅ Lido: consumo_6090.parquet (8016 linhas)
# ✅ Lido: consumo_6100.parquet (8016 linhas)
# ✅ Lido: consumo_6110.parquet (8016 linhas)
# ✅ Lido: consumo_6120.parquet (8016 linhas)
# ✅ Lido: consumo_6150.parquet (8016 linhas)
# ✅ Lido: consumo_6160.parquet (8016 linhas)
# ✅ Lido: consumo_6185.parquet (8016 linhas)
# ✅ Lido: consumo_6200.parquet (8016 linhas)
# ✅ Lido: consumo_6215.parquet (8016 linhas)
# ✅ Lido: consumo_6225.parquet (8016 linhas)
# ✅ Lido: consumo_6230.parquet (8016 linhas)
# ✅ Lido: consumo_6250.parquet (8016 linhas)
# ✅ Lido: consumo_6260.parquet (8016 linhas)
# ✅ Lido: consumo_6270.parquet (8016 linhas)
# ✅ Lido: consumo_6285.parquet (8016 linhas)
# ✅ Lido: consumo_6290.parquet (8016 linhas)
# ✅ Lido: consumo_6300.parquet (8016 linhas)
# ✅ Lido: consumo_6320.parquet (8016 linhas)
# ✅ Lido: consumo_6350.parquet (8016 linhas)
# ✅ Lido: consumo_6355.parquet (8016 linhas)
# ✅ Lido: consumo_6360.parquet (8016 linhas)
# ✅ Lido: consumo_6370.parquet (8016 linhas)
# ✅ Lido: consumo_6400.parquet (8016 linhas)
# ✅ Lido: consumo_6420.parquet (8016 linhas)
# ✅ Lido: consumo_6430.parquet (8016 linhas)
# ✅ Lido: consumo_6440.parquet (8016 linhas)
# ✅ Lido: consumo_7000.parquet (8016 linhas)
# ✅ Lido: consumo_7005.parquet (8016 linhas)
# ✅ Lido: consumo_7040.parquet (8016 linhas)
# ✅ Lido: consumo_7050.parquet (8016 linhas)
# ✅ Lido: consumo_7080.parquet (8016 linhas)
# ✅ Lido: consumo_7090.parquet (8016 linhas)
# ✅ Lido: consumo_7100.parquet (8016 linhas)
# ✅ Lido: consumo_7150.parquet (8016 linhas)
# ✅ Lido: consumo_7160.parquet (8016 linhas)
# ✅ Lido: consumo_7170.parquet (8016 linhas)
# ✅ Lido: consumo_7200.parquet (8016 linhas)
# ✅ Lido: consumo_7220.parquet (8016 linhas)
# ✅ Lido: consumo_7230.parquet (8016 linhas)
# ✅ Lido: consumo_7240.parquet (8016 linhas)
# ✅ Lido: consumo_7250.parquet (8016 linhas)
# ✅ Lido: consumo_7300.parquet (8016 linhas)
# ✅ Lido: consumo_7320.parquet (8016 linhas)
# ✅ Lido: consumo_7330.parquet (8016 linhas)
# ✅ Lido: consumo_7340.parquet (8016 linhas)
# ✅ Lido: consumo_7350.parquet (8016 linhas)
# ✅ Lido: consumo_7370.parquet (8016 linhas)
# ✅ Lido: consumo_7400.parquet (8016 linhas)
# ✅ Lido: consumo_7425.parquet (8016 linhas)
# ✅ Lido: consumo_7430.parquet (8016 linhas)
# ✅ Lido: consumo_7440.parquet (8016 linhas)
# ✅ Lido: consumo_7450.parquet (8016 linhas)
# ✅ Lido: consumo_7460.parquet (8016 linhas)
# ✅ Lido: consumo_7470.parquet (8016 linhas)
# ✅ Lido: consumo_7480.parquet (8016 linhas)
# ✅ Lido: consumo_7490.parquet (8016 linhas)
# ✅ Lido: consumo_7500.parquet (8016 linhas)
# ✅ Lido: consumo_7520.parquet (8016 linhas)
# ✅ Lido: consumo_7540.parquet (8016 linhas)
# ✅ Lido: consumo_7555.parquet (8016 linhas)
# ✅ Lido: consumo_7565.parquet (8016 linhas)
# ✅ Lido: consumo_7570.parquet (8016 linhas)
# ✅ Lido: consumo_7580.parquet (8016 linhas)
# ✅ Lido: consumo_7595.parquet (8016 linhas)
# ✅ Lido: consumo_7600.parquet (8016 linhas)
# ✅ Lido: consumo_7630.parquet (8016 linhas)
# ✅ Lido: consumo_7645.parquet (8016 linhas)
# ✅ Lido: consumo_7665.parquet (8016 linhas)
# ✅ Lido: consumo_7670.parquet (8016 linhas)
# ✅ Lido: consumo_7700.parquet (8016 linhas)
# ✅ Lido: consumo_7750.parquet (8016 linhas)
# ✅ Lido: consumo_7780.parquet (8016 linhas)
# ✅ Lido: consumo_7800.parquet (8016 linhas)
# ✅ Lido: consumo_7830.parquet (8016 linhas)
# ✅ Lido: consumo_7860.parquet (8016 linhas)
# ✅ Lido: consumo_7875.parquet (8016 linhas)
# ✅ Lido: consumo_7885.parquet (8016 linhas)
# ✅ Lido: consumo_7900.parquet (8016 linhas)
# ✅ Lido: consumo_7920.parquet (8016 linhas)
# ✅ Lido: consumo_7940.parquet (8016 linhas)
# ✅ Lido: consumo_7960.parquet (8016 linhas)
# ✅ Lido: consumo_8000.parquet (8016 linhas)
# ✅ Lido: consumo_8005.parquet (8016 linhas)
# ✅ Lido: consumo_8100.parquet (8016 linhas)
# ✅ Lido: consumo_8125.parquet (8016 linhas)
# ✅ Lido: consumo_8135.parquet (8016 linhas)
# ✅ Lido: consumo_8150.parquet (8016 linhas)
# ✅ Lido: consumo_8200.parquet (8016 linhas)
# ✅ Lido: consumo_8300.parquet (8016 linhas)
# ✅ Lido: consumo_8365.parquet (8016 linhas)
# ✅ Lido: consumo_8375.parquet (8016 linhas)
# ✅ Lido: consumo_8400.parquet (8016 linhas)
# ✅ Lido: consumo_8500.parquet (8016 linhas)
# ✅ Lido: consumo_8550.parquet (8016 linhas)
# ✅ Lido: consumo_8600.parquet (8016 linhas)
# ✅ Lido: consumo_8650.parquet (8016 linhas)
# ✅ Lido: consumo_8670.parquet (8016 linhas)
# ✅ Lido: consumo_8700.parquet (8016 linhas)
# ✅ Lido: consumo_8800.parquet (8016 linhas)
# ✅ Lido: consumo_8900.parquet (8016 linhas)
# ✅ Lido: consumo_8950.parquet (8016 linhas)
# ✅ Lido: consumo_8970.parquet (8016 linhas)

# %%
df_total = pd.concat(dataframes, ignore_index=True) # Junta todos os DataFrames da lista 'dataframes' num único DataFrame

df_total["DateTime"] = pd.to_datetime(df_total["DateTime"])  # Converte a coluna "DateTime" para o tipo datetime, caso ainda não esteja nesse formato
df_total = df_total.sort_values("DateTime") # Ordena os dados pela coluna "DateTime" em ordem crescente

print(f"\n📦 Total combinado: {len(df_total)} linhas") # Imprime o número total de linhas após a concatenação
# Out:
# 📦 Total combinado: 3719423 linhas

# %%
# Guardar versão limpa do dataset como .parquet

df_total = df_total[df_total['ActiveEnergy(kWh)'] >= 0] # Filtra o DataFrame para manter apenas os registos com energia ativa maior ou igual a 0 (remove valores negativos que podem indicar erros ou dados inválidos)
df_total.to_parquet("../datasets/consumo_eredes_customizado.parquet", index=False) # Guarda o DataFrame filtrado num ficheiro .parquet na pasta indicada, sem incluir o índice
print("✅ Ficheiro combinado guardado em: datasets/consumo_eredes_customizado.parquet") # Imprime uma mensagem a confirmar que o ficheiro foi guardado com sucesso
# Out:
# ✅ Ficheiro combinado guardado em: datasets/consumo_eredes_customizado.parquet

# %%
# Apagar pasta "datasetsPorCP"

for root, dirs, files in os.walk(caminho_da_pasta, topdown=False): # Apagar todos os ficheiros e subpastas dentro da pasta. Usa os.walk() com topdown=False para começar pelas subpastas mais profundas e evitar erros ao apagar diretórios
    for name in files:
        os.remove(os.path.join(root, name)) # Apaga cada ficheiro encontrado
    for name in dirs:
        os.rmdir(os.path.join(root, name)) # Apaga cada subpasta encontrada

os.rmdir(caminho_da_pasta) # Após esvaziar o conteúdo, apaga a própria pasta principal

# %%
df_total.head() # Mostra as primeiras 5 linhas do DataFrame df_total (útil para inspeção rápida dos dados)
# Out:
#           DateTime        Date  Hour ZipCode  ActiveEnergy(kWh)  Day  Month  \
# 0       2022-11-01  2022-11-01     0    1000        9328.306723    1     11
# 1186368 2022-11-01  2022-11-01     0    3045        4293.076725    1     11
# 1194384 2022-11-01  2022-11-01     0    3050        6608.606545    1     11
# 1202400 2022-11-01  2022-11-01     0    3060       16832.631994    1     11
# 1210416 2022-11-01  2022-11-01     0    3070        5894.381217    1     11
#
#          Year  IsWeekend TimeOfDay DayOfTheWeek  Season  IsHoliday  \
# 0        2022          0     Noite        Terça  Outono          1
# 1186368  2022          0     Noite        Terça  Outono          1
# 1194384  2022          0     Noite        Terça  Outono          1
# 1202400  2022          0     Noite        Terça  Outono          1
# 1210416  2022          0     Noite        Terça  Outono          1
#
#          Temperature  PopulationDensity
# 0               15.5            5455.23
# 1186368         11.4             440.88
# 1194384         11.4             440.88
# 1202400         11.4             440.88
# 1210416         11.4             440.88

# %% [markdown]
# ### Dataset Limpo
# - Nome: `consumo_eredes_customizado.parquet`
# - Colunas mantidas: `Hour`, `Active Energy (kWh)`, `Day of the Week`
# - Colunas criadas: `DateTime`, `Date`, `Day`, `Month`, `Year`, `IsWeekend`, `TimeOfDay`, `Season`, `isHoliday`, `Temperature`, `PopulationDensity`
# - `DateTime` ordenado cronologicamente
